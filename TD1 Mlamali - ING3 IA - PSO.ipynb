# %% [markdown]
# # Particle Swarm Optimization (PSO)

# %% [markdown]
# ## Import libraries

# %%
# Some libraries
from matplotlib.pyplot import semilogy
from functools import *
import numpy as np
import sys
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import plotly.express as px
import plotly.graph_objects as go

# %%
PLOTS_DIR_PATH = "/content/gdrive/Shareddrives/• ING3 (2022-23) /Optimisation Métaheuristique/1. Optimisation stochastique multi-agents (DE, PSO, ABC)/TDs/td1 - plot results"

# %% [markdown]
# ## Parameters

# %% [markdown]
# ![alt text](images/parameter_tuning.png)

# %% [markdown]
# - PSI : Permet de définir la capacité de l'essaim à changer de direction. Les particules ont une inertie proportionnelle à ce coefficient (l'inertie d'un corps est sa tendance à conserver sa vitesse)
#
# - the $c_1$ hyperparameter allows defining the ability of the group to be influenced by the **best personal solutions** found over the iterations.
# - The hyperparameter $c_2$  allows defining the ability of the group to be influenced by the **best global solution** found over the iterations.

# %%
FUNCTION = "eggholder"
DIM = 2  # problem dimension
# domain of variation definition
INFS = [-512] * DIM  # pour chaque dimension on a une borne inf
SUPS = [512] * DIM  # pour chaque dimension on a une borne sup

ITER_MAX = 1000
N_PARTICLES = int(10 + 2 * np.sqrt(DIM))  # number of particles in the swarm
# usual params
PSI, CMAX = (0.7, 1.47)  #todo cmax c'est quoi ?

# psi,cmax = (0.8, 1.62)
N_PARTICLES
# Out:
# 12

# %%
from benchmarks import get_evaluation_by_name

get_evaluation_by_name(FUNCTION)  # Evaluation function
# Out:
# <function benchmarks.eggholder(sol)>

# %% [markdown]
# ## Initialization
#
# ### Particle
#
# create a particle
# one particle is discribed by :
#   - pos : solution list of variables
#   - vit : movement velocity (null at the initialization)
#   - fit :  fitness of the solution
#   - bestpos : best visited position
#   - bestfit : evaluation of the best visited solution
#   - bestvois : best neighbor (global for this version)

# %%
def init_one(dim: int, inf: list, sup: list, eval_func=get_evaluation_by_name(FUNCTION)):
    """
    Return a particle with random position and null velocity.
    bestpos and bestfit refer to the best position and fitness found by the particle itself.
    bestvois refers to the best particle's neighbors.
    """
    pos = np.array([np.random.uniform(inf[i], sup[i]) for i in range(dim)])
    fit = eval_func(pos)  # evaluation of the solution
    return {'vit': np.zeros(dim), 'pos': pos, 'fit': fit, 'bestpos': pos[:], 'bestfit': fit, 'bestvois': None}


init_one(DIM, INFS, SUPS)
# Out:
# {'vit': array([0., 0.]),
#  'pos': array([-26.22894759, -17.16668429]),
#  'fit': 20.980040325174585,
#  'bestpos': array([-26.22894759, -17.16668429]),
#  'bestfit': 20.980040325174585,
#  'bestvois': None}

# %% [markdown]
# ### Population (swarm)

# %%
# Init of the population (swarm)
def init_swarm(n, dim: int, inf: list, sup: list):
    return [init_one(dim, inf, sup) for _ in range(n)]


swarm_test = init_swarm(N_PARTICLES, DIM, INFS, SUPS)
swarm_test
# Out:
# [{'vit': array([0., 0.]),
#   'pos': array([-250.65376739, -459.85785562]),
#   'fit': -459.62756592915923,
#   'bestpos': array([-250.65376739, -459.85785562]),
#   'bestfit': -459.62756592915923,
#   'bestvois': None},
#  {'vit': array([0., 0.]),
#   'pos': array([-132.93053965, -380.33637258]),
#   'fit': 171.6728808797955,
#   'bestpos': array([-132.93053965, -380.33637258]),
#   'bestfit': 171.6728808797955,
#   'bestvois': None},
#  {'vit': array([0., 0.]),
#   'pos': array([-291.37477544, -293.82675682]),
#   'fit': 400.94388142577805,
#   'bestpos': array([-291.37477544, -293.82675682]),
#   'bestfit': 400.94388142577805,
#   'bestvois': None},
#  {'vit': array([0., 0.]),
#   'pos': array([-197.834336  ,  418.66981114]),
#   'fit': -327.0233819088063,
#   'bestpos': array([-197.834336  ,  418.66981114]),
#   'bestfit': -327.0233819088063,
#   'bestvois': None},
#  {'vit': array([0., 0.]),
#   'pos': array([256.68980001, 441.86407975]),
#   'fit': 325.5495333692084,
#   'bestpos': array([256.68980001, 441.86407975]),
#   'bestfit': 325.5495333692084,
#   'bestvois': None},
#  {'vit': array([0., 0.]),
#   'pos': array([ -46.25277388, -445.67512972]),
#   'fit': 431.0541314394121,
#   'bestpos': array([ -46.25277388, -445.67512972]),
#   'bestfit': 431.0541314394121,
#   'bestvois': None},
#  {'vit': array([0., 0.]),
#   'pos': array([163.13193983, 145.34533128]),
#   'fit': -16.51535459869868,
#   'bestpos': array([163.13193983, 145.34533128]),
#   'bestfit': -16.51535459869868,
#   'bestvois': None},
#  {'vit': array([0., 0.]),
#   'pos': array([ -66.25986064, -457.11631861]),
#   'fit': 388.6434851345762,
#   'bestpos': array([ -66.25986064, -457.11631861]),
#   'bestfit': 388.6434851345762,
#   'bestvois': None},
#  {'vit': array([0., 0.]),
#   'pos': array([ 117.03460679, -209.66204056]),
#   'fit': -168.65627451914082,
#   'bestpos': array([ 117.03460679, -209.66204056]),
#   'bestfit': -168.65627451914082,
#   'bestvois': None},
#  {'vit': array([0., 0.]),
#   'pos': array([-262.5424401 ,  217.14782875]),
#   'fit': 471.420082092233,
#   'bestpos': array([-262.5424401 ,  217.14782875]),
#   'bestfit': 471.420082092233,
#   'bestvois': None},
#  {'vit': array([0., 0.]),
#   'pos': array([-464.51896933,  119.67270077]),
#   'fit': -592.3062133151341,
#   'bestpos': array([-464.51896933,  119.67270077]),
#   'bestfit': -592.3062133151341,
#   'bestvois': None},
#  {'vit': array([0., 0.]),
#   'pos': array([-340.66450571,   56.61453356]),
#   'fit': -143.9942222917631,
#   'bestpos': array([-340.66450571,   56.61453356]),
#   'bestfit': -143.9942222917631,
#   'bestvois': None}]

# %% [markdown]
# ### Plot the swarm

# %%
def plot_swarm(swarm: list, dim: int, infs: list, sups: list, eval_func=get_evaluation_by_name(FUNCTION),
               title: str = "Swarm"):
    """
    Plot the swarm in the search space.
    """
    if (dim > 2):
        print("Plotting is only possible for 2D and 3D problems")
        return

    if (dim == 2):
        # square figure
        fig, ax = plt.subplots(figsize=(7, 6))
        # plot function
        x = np.linspace(infs[0], sups[0], 100)
        y = np.linspace(infs[1], sups[1], 100)
        X, Y = np.meshgrid(x, y)
        Z = eval_func(np.array([X, Y]))
        ax.contour(X, Y, Z, 20, cmap='viridis', zorder=0)
        # add range bar on the right
        fig.colorbar(ax.contourf(X, Y, Z, 20, cmap='viridis'), ax=ax, shrink=0.9, aspect=10)
        # Plot the swarm (top view)
        ax.set_xlim(infs[0], sups[0])
        ax.set_ylim(infs[1], sups[1])
        ax.set_xlabel("x1")
        ax.set_ylabel("x2")
        ax.set_title(title)
        # Plot the swarm
        for particle in swarm:
            ax.scatter(particle["pos"][0], particle["pos"][1], color="red", s=50, zorder=10, marker="x")

    plt.show()


plot_swarm(swarm_test, DIM, INFS, SUPS)

# %%
history_swarm_test = [init_swarm(N_PARTICLES, DIM, INFS, SUPS) for _ in range(ITER_MAX)]

# %%
n_subplots = 10
len_history = len(history_swarm_test)
step = len_history // n_subplots if len_history > n_subplots else 1
indexes = list(range(0,len_history,step))
indexes = indexes + [len_history-1] if indexes[-1] != len_history-1 else indexes
# delete the before last index
indexes = indexes[:-2] + [indexes[-1]] if len(indexes) > n_subplots else indexes
swarm_to_plot = [history_swarm_test[k] for k in indexes]

indexes
# Out:
# [0, 100, 200, 300, 400, 500, 600, 700, 800, 999]

# %%
[history_swarm_test[k] for k in range(0,len(history_swarm_test),100)]
# Out:
# [[{'vit': array([0., 0.]),
#    'pos': array([119.69329931, 179.1263826 ]),
#    'fit': 255.8776756270774,
#    'bestpos': array([119.69329931, 179.1263826 ]),
#    'bestfit': 255.8776756270774,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 420.01841455, -222.91966386]),
#    'fit': -456.2274804307781,
#    'bestpos': array([ 420.01841455, -222.91966386]),
#    'bestfit': -456.2274804307781,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-370.76069081,  471.6418902 ]),
#    'fit': 316.78695583464463,
#    'bestpos': array([-370.76069081,  471.6418902 ]),
#    'bestfit': 316.78695583464463,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([472.23900328, 296.59999991]),
#    'fit': -35.453283462418085,
#    'bestpos': array([472.23900328, 296.59999991]),
#    'bestfit': -35.453283462418085,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-479.34798703,  267.14528442]),
#    'fit': 239.49499411624222,
#    'bestpos': array([-479.34798703,  267.14528442]),
#    'bestfit': 239.49499411624222,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-22.01398259, 405.12393758]),
#    'fit': -364.30114183749316,
#    'bestpos': array([-22.01398259, 405.12393758]),
#    'bestfit': -364.30114183749316,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-143.16782154,  251.13152377]),
#    'fit': -212.30243981293216,
#    'bestpos': array([-143.16782154,  251.13152377]),
#    'bestfit': -212.30243981293216,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-364.34978482,   35.45847506]),
#    'fit': 19.71059754804607,
#    'bestpos': array([-364.34978482,   35.45847506]),
#    'bestfit': 19.71059754804607,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([  73.92106543, -220.56446321]),
#    'fit': -106.87140095323426,
#    'bestpos': array([  73.92106543, -220.56446321]),
#    'bestfit': -106.87140095323426,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-288.24667936,  307.36761571]),
#    'fit': -616.7707814579966,
#    'bestpos': array([-288.24667936,  307.36761571]),
#    'bestfit': -616.7707814579966,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([207.31081816, 367.93204616]),
#    'fit': 487.9172997802511,
#    'bestpos': array([207.31081816, 367.93204616]),
#    'bestfit': 487.9172997802511,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-38.48898975,   9.78884928]),
#    'fit': 43.63095423175176,
#    'bestpos': array([-38.48898975,   9.78884928]),
#    'bestfit': 43.63095423175176,
#    'bestvois': None}],
#  [{'vit': array([0., 0.]),
#    'pos': array([327.1158647 , -79.81947578]),
#    'fit': -236.7703732893102,
#    'bestpos': array([327.1158647 , -79.81947578]),
#    'bestfit': -236.7703732893102,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-153.475976  , -394.57352492]),
#    'fit': 195.67507664421757,
#    'bestpos': array([-153.475976  , -394.57352492]),
#    'bestfit': 195.67507664421757,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-193.16317633, -186.79822426]),
#    'fit': 63.364971343229044,
#    'bestpos': array([-193.16317633, -186.79822426]),
#    'bestfit': 63.364971343229044,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-334.20817263, -455.70486943]),
#    'fit': -236.2792780820164,
#    'bestpos': array([-334.20817263, -455.70486943]),
#    'bestfit': -236.2792780820164,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-473.7713323 ,  -25.20945953]),
#    'fit': 420.9256581257293,
#    'bestpos': array([-473.7713323 ,  -25.20945953]),
#    'bestfit': 420.9256581257293,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-497.44172992,  419.6354479 ]),
#    'fit': -846.1020615125492,
#    'bestpos': array([-497.44172992,  419.6354479 ]),
#    'bestfit': -846.1020615125492,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([290.14890666, -65.54588695]),
#    'fit': -290.20456259544113,
#    'bestpos': array([290.14890666, -65.54588695]),
#    'bestfit': -290.20456259544113,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-373.73343316,   34.65762178]),
#    'fit': 120.20086872720273,
#    'bestpos': array([-373.73343316,   34.65762178]),
#    'bestfit': 120.20086872720273,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-363.16337633, -471.61091653]),
#    'fit': -243.65563179936714,
#    'bestpos': array([-363.16337633, -471.61091653]),
#    'bestfit': -243.65563179936714,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 269.38453602, -315.31209363]),
#    'fit': -227.00607788132018,
#    'bestpos': array([ 269.38453602, -315.31209363]),
#    'bestfit': -227.00607788132018,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-19.98206166,   5.90581296]),
#    'fit': -33.84105171185303,
#    'bestpos': array([-19.98206166,   5.90581296]),
#    'bestfit': -33.84105171185303,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-476.30743255, -498.89014355]),
#    'fit': 830.6226372010237,
#    'bestpos': array([-476.30743255, -498.89014355]),
#    'bestfit': 830.6226372010237,
#    'bestvois': None}],
#  [{'vit': array([0., 0.]),
#    'pos': array([ 76.0168681 , 194.09817013]),
#    'fit': 138.97385211897657,
#    'bestpos': array([ 76.0168681 , 194.09817013]),
#    'bestfit': 138.97385211897657,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-315.27473182,  453.4977874 ]),
#    'fit': 474.7656326194657,
#    'bestpos': array([-315.27473182,  453.4977874 ]),
#    'bestfit': 474.7656326194657,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 130.40097556, -481.10636729]),
#    'fit': 86.08329198557797,
#    'bestpos': array([ 130.40097556, -481.10636729]),
#    'bestfit': 86.08329198557797,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-300.56263075,  293.32904395]),
#    'fit': -615.4410732988381,
#    'bestpos': array([-300.56263075,  293.32904395]),
#    'bestfit': -615.4410732988381,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-328.50016088, -205.55880412]),
#    'fit': 91.73618672631055,
#    'bestpos': array([-328.50016088, -205.55880412]),
#    'bestfit': 91.73618672631055,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-208.42752471,   27.11524098]),
#    'fit': 244.48797453382318,
#    'bestpos': array([-208.42752471,   27.11524098]),
#    'bestfit': 244.48797453382318,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([265.73838236, 384.10151493]),
#    'fit': 203.3900418122375,
#    'bestpos': array([265.73838236, 384.10151493]),
#    'bestfit': 203.3900418122375,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([274.90224326, 465.91671885]),
#    'fit': -37.90744458818108,
#    'bestpos': array([274.90224326, 465.91671885]),
#    'bestfit': -37.90744458818108,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-32.73953193, -94.58807492]),
#    'fit': 19.404981359074753,
#    'bestpos': array([-32.73953193, -94.58807492]),
#    'bestfit': 19.404981359074753,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([421.46593274, 370.60998142]),
#    'fit': 217.44343419916632,
#    'bestpos': array([421.46593274, 370.60998142]),
#    'bestfit': 217.44343419916632,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-299.42202697,  178.96468461]),
#    'fit': 137.06003413034918,
#    'bestpos': array([-299.42202697,  178.96468461]),
#    'bestfit': 137.06003413034918,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([431.86017714, -60.75179204]),
#    'fit': 421.9274622764942,
#    'bestpos': array([431.86017714, -60.75179204]),
#    'bestfit': 421.9274622764942,
#    'bestvois': None}],
#  [{'vit': array([0., 0.]),
#    'pos': array([ -89.00005247, -378.06628161]),
#    'fit': 123.33355245776009,
#    'bestpos': array([ -89.00005247, -378.06628161]),
#    'bestfit': 123.33355245776009,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-43.16209193,   0.69568481]),
#    'fit': 86.2562060856867,
#    'bestpos': array([-43.16209193,   0.69568481]),
#    'bestfit': 86.2562060856867,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 16.33271362, 498.11622046]),
#    'fit': 529.8421973083732,
#    'bestpos': array([ 16.33271362, 498.11622046]),
#    'bestfit': 529.8421973083732,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 49.02783061, 361.92159773]),
#    'fit': -349.2248036146931,
#    'bestpos': array([ 49.02783061, 361.92159773]),
#    'bestfit': -349.2248036146931,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 123.9278828 , -226.70252091]),
#    'fit': -287.7627325215668,
#    'bestpos': array([ 123.9278828 , -226.70252091]),
#    'bestfit': -287.7627325215668,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([304.52249991, 223.44182982]),
#    'fit': 21.08166844942889,
#    'bestpos': array([304.52249991, 223.44182982]),
#    'bestfit': 21.08166844942889,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-492.28653095,    5.12811734]),
#    'fit': 291.0500909212451,
#    'bestpos': array([-492.28653095,    5.12811734]),
#    'bestfit': 291.0500909212451,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-412.67033118,  318.2733731 ]),
#    'fit': 336.6859216680738,
#    'bestpos': array([-412.67033118,  318.2733731 ]),
#    'bestfit': 336.6859216680738,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([   9.52635559, -357.83327268]),
#    'fit': -313.1102022224568,
#    'bestpos': array([   9.52635559, -357.83327268]),
#    'bestfit': -313.1102022224568,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([443.70293167, 252.38474753]),
#    'fit': 104.3017820045819,
#    'bestpos': array([443.70293167, 252.38474753]),
#    'bestfit': 104.3017820045819,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-3.06271149,  2.93966109]),
#    'fit': -30.818741438147278,
#    'bestpos': array([-3.06271149,  2.93966109]),
#    'bestfit': -30.818741438147278,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([434.57288975,  25.86593874]),
#    'fit': -190.1749457494234,
#    'bestpos': array([434.57288975,  25.86593874]),
#    'bestfit': -190.1749457494234,
#    'bestvois': None}],
#  [{'vit': array([0., 0.]),
#    'pos': array([311.33615665, 270.62965407]),
#    'fit': -92.73247317777502,
#    'bestpos': array([311.33615665, 270.62965407]),
#    'bestfit': -92.73247317777502,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-212.13087467,  331.30507593]),
#    'fit': 208.5914496798823,
#    'bestpos': array([-212.13087467,  331.30507593]),
#    'bestfit': 208.5914496798823,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-408.91578537, -133.00691157]),
#    'fit': 139.86108027490943,
#    'bestpos': array([-408.91578537, -133.00691157]),
#    'bestfit': 139.86108027490943,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([302.9614431,  -5.0673841]),
#    'fit': -38.60385199067112,
#    'bestpos': array([302.9614431,  -5.0673841]),
#    'bestfit': -38.60385199067112,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([219.04336949, 130.43204318]),
#    'fit': 341.75378804134743,
#    'bestpos': array([219.04336949, 130.43204318]),
#    'bestfit': 341.75378804134743,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-371.17865848,  266.22501406]),
#    'fit': 24.01426777146486,
#    'bestpos': array([-371.17865848,  266.22501406]),
#    'bestfit': 24.01426777146486,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([319.47654155, 269.76574855]),
#    'fit': 76.0195024633432,
#    'bestpos': array([319.47654155, 269.76574855]),
#    'bestfit': 76.0195024633432,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([184.50611097, -28.88467767]),
#    'fit': 92.67560299982219,
#    'bestpos': array([184.50611097, -28.88467767]),
#    'bestfit': 92.67560299982219,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([  91.76090909, -487.36172039]),
#    'fit': 383.4797949541092,
#    'bestpos': array([  91.76090909, -487.36172039]),
#    'bestfit': 383.4797949541092,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-479.86449524,  297.94349862]),
#    'fit': 706.8276679421862,
#    'bestpos': array([-479.86449524,  297.94349862]),
#    'bestfit': 706.8276679421862,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-403.33649671,  350.74280269]),
#    'fit': 6.633087529825616,
#    'bestpos': array([-403.33649671,  350.74280269]),
#    'bestfit': 6.633087529825616,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 88.53649185, 336.06372156]),
#    'fit': -459.50949377707224,
#    'bestpos': array([ 88.53649185, 336.06372156]),
#    'bestfit': -459.50949377707224,
#    'bestvois': None}],
#  [{'vit': array([0., 0.]),
#    'pos': array([402.03644896, 168.01191353]),
#    'fit': 134.94234191627464,
#    'bestpos': array([402.03644896, 168.01191353]),
#    'bestfit': 134.94234191627464,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([176.18233809, 477.02889772]),
#    'fit': 239.2827582380535,
#    'bestpos': array([176.18233809, 477.02889772]),
#    'bestfit': 239.2827582380535,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 502.06125923, -430.76096421]),
#    'fit': -275.0030631333549,
#    'bestpos': array([ 502.06125923, -430.76096421]),
#    'bestfit': -275.0030631333549,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([121.34869206, 100.21472128]),
#    'fit': -253.18598119284053,
#    'bestpos': array([121.34869206, 100.21472128]),
#    'bestfit': -253.18598119284053,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([370.51889141, -42.9960691 ]),
#    'fit': -191.51906538947222,
#    'bestpos': array([370.51889141, -42.9960691 ]),
#    'bestfit': -191.51906538947222,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 227.91389551, -224.22766443]),
#    'fit': 254.55813364394615,
#    'bestpos': array([ 227.91389551, -224.22766443]),
#    'bestfit': 254.55813364394615,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-431.51473771, -219.60027466]),
#    'fit': 247.88949968205972,
#    'bestpos': array([-431.51473771, -219.60027466]),
#    'bestfit': 247.88949968205972,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([  74.74583271, -481.86177058]),
#    'fit': 425.04641085123876,
#    'bestpos': array([  74.74583271, -481.86177058]),
#    'bestfit': 425.04641085123876,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-441.74111748,  -78.66391854]),
#    'fit': -393.4802779798648,
#    'bestpos': array([-441.74111748,  -78.66391854]),
#    'bestfit': -393.4802779798648,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([433.11063266,  67.92277786]),
#    'fit': -361.1926983840423,
#    'bestpos': array([433.11063266,  67.92277786]),
#    'bestfit': -361.1926983840423,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([273.17073794, 207.59820736]),
#    'fit': 49.20831106472076,
#    'bestpos': array([273.17073794, 207.59820736]),
#    'bestfit': 49.20831106472076,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-185.0005165 , -204.78888613]),
#    'fit': 157.97581981091582,
#    'bestpos': array([-185.0005165 , -204.78888613]),
#    'bestfit': 157.97581981091582,
#    'bestvois': None}],
#  [{'vit': array([0., 0.]),
#    'pos': array([66.99284719, 88.98340665]),
#    'fit': 4.82150839740558,
#    'bestpos': array([66.99284719, 88.98340665]),
#    'bestfit': 4.82150839740558,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 112.28798426, -369.76111397]),
#    'fit': -92.56989571917656,
#    'bestpos': array([ 112.28798426, -369.76111397]),
#    'bestfit': -92.56989571917656,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-444.67819556, -454.71513841]),
#    'fit': 411.60553626128853,
#    'bestpos': array([-444.67819556, -454.71513841]),
#    'bestfit': 411.60553626128853,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 163.09113736, -290.64136702]),
#    'fit': 101.48123343739832,
#    'bestpos': array([ 163.09113736, -290.64136702]),
#    'bestfit': 101.48123343739832,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-284.66570184,   53.56467313]),
#    'fit': -296.1842760553697,
#    'bestpos': array([-284.66570184,   53.56467313]),
#    'bestfit': -296.1842760553697,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-412.86156721,  502.47704427]),
#    'fit': -206.74573148460513,
#    'bestpos': array([-412.86156721,  502.47704427]),
#    'bestfit': -206.74573148460513,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-379.80535013,  321.10105702]),
#    'fit': -98.2106361129448,
#    'bestpos': array([-379.80535013,  321.10105702]),
#    'bestfit': -98.2106361129448,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([309.29708148, -44.01394315]),
#    'fit': -283.3108245038538,
#    'bestpos': array([309.29708148, -44.01394315]),
#    'bestfit': -283.3108245038538,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([322.73958195,  47.31925752]),
#    'fit': 277.77468395309523,
#    'bestpos': array([322.73958195,  47.31925752]),
#    'bestfit': 277.77468395309523,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 430.18039648, -172.10483354]),
#    'fit': -154.49684109478417,
#    'bestpos': array([ 430.18039648, -172.10483354]),
#    'bestfit': -154.49684109478417,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([380.25876732, 214.40378398]),
#    'fit': -518.623760855802,
#    'bestpos': array([380.25876732, 214.40378398]),
#    'bestfit': -518.623760855802,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 107.34742996, -428.04833474]),
#    'fit': -171.1000669512249,
#    'bestpos': array([ 107.34742996, -428.04833474]),
#    'bestfit': -171.1000669512249,
#    'bestvois': None}],
#  [{'vit': array([0., 0.]),
#    'pos': array([ 345.07603953, -449.56431231]),
#    'fit': 439.27678693188705,
#    'bestpos': array([ 345.07603953, -449.56431231]),
#    'bestfit': 439.27678693188705,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-405.89902862,  128.15990438]),
#    'fit': 116.74535831818173,
#    'bestpos': array([-405.89902862,  128.15990438]),
#    'bestfit': 116.74535831818173,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([248.0715172 , 149.05032601]),
#    'fit': 275.53841340339824,
#    'bestpos': array([248.0715172 , 149.05032601]),
#    'bestfit': 275.53841340339824,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([230.76214446,   5.19530212]),
#    'fit': 146.50118364579433,
#    'bestpos': array([230.76214446,   5.19530212]),
#    'bestfit': 146.50118364579433,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-92.39475431, 157.206211  ]),
#    'fit': 91.19063687749794,
#    'bestpos': array([-92.39475431, 157.206211  ]),
#    'bestfit': 91.19063687749794,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([  86.25223513, -338.19858273]),
#    'fit': -36.0190341544003,
#    'bestpos': array([  86.25223513, -338.19858273]),
#    'bestfit': -36.0190341544003,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-228.70207167,  366.95618278]),
#    'fit': 187.25320027074005,
#    'bestpos': array([-228.70207167,  366.95618278]),
#    'bestfit': 187.25320027074005,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-360.43911462,   39.56629094]),
#    'fit': -0.373677069280955,
#    'bestpos': array([-360.43911462,   39.56629094]),
#    'bestfit': -0.373677069280955,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-433.99025993, -393.94058156]),
#    'fit': -130.93454023803042,
#    'bestpos': array([-433.99025993, -393.94058156]),
#    'bestfit': -130.93454023803042,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-313.01610299, -171.47806877]),
#    'fit': -200.2545306367153,
#    'bestpos': array([-313.01610299, -171.47806877]),
#    'bestfit': -200.2545306367153,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-86.05125586, 128.18324881]),
#    'fit': 184.4633757202445,
#    'bestpos': array([-86.05125586, 128.18324881]),
#    'bestfit': 184.4633757202445,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-224.1922103 ,  443.71864234]),
#    'fit': -328.3373554746408,
#    'bestpos': array([-224.1922103 ,  443.71864234]),
#    'bestfit': -328.3373554746408,
#    'bestvois': None}],
#  [{'vit': array([0., 0.]),
#    'pos': array([232.56083773, -59.25815794]),
#    'fit': 91.01506061235457,
#    'bestpos': array([232.56083773, -59.25815794]),
#    'bestfit': 91.01506061235457,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-197.42183315, -331.15332373]),
#    'fit': 338.61874186072924,
#    'bestpos': array([-197.42183315, -331.15332373]),
#    'bestfit': 338.61874186072924,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-438.73827394, -213.21790468]),
#    'fit': 430.83210760624775,
#    'bestpos': array([-438.73827394, -213.21790468]),
#    'bestfit': 430.83210760624775,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([247.82821839, 197.86093855]),
#    'fit': 16.72892660374515,
#    'bestpos': array([247.82821839, 197.86093855]),
#    'bestfit': 16.72892660374515,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([478.86798057, 260.39355616]),
#    'fit': 567.1576860867056,
#    'bestpos': array([478.86798057, 260.39355616]),
#    'bestfit': 567.1576860867056,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 130.87149336, -472.56777079]),
#    'fit': 6.707078518567222,
#    'bestpos': array([ 130.87149336, -472.56777079]),
#    'bestfit': 6.707078518567222,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([260.71863846, 135.72670634]),
#    'fit': 31.30725365572883,
#    'bestpos': array([260.71863846, 135.72670634]),
#    'bestfit': 31.30725365572883,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-460.63170554, -312.53248416]),
#    'fit': -343.87972293247725,
#    'bestpos': array([-460.63170554, -312.53248416]),
#    'bestfit': -343.87972293247725,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([182.26520004, 462.20746101]),
#    'fit': 221.82589441274368,
#    'bestpos': array([182.26520004, 462.20746101]),
#    'bestfit': 221.82589441274368,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 317.24149859, -354.30432116]),
#    'fit': -427.5102143577257,
#    'bestpos': array([ 317.24149859, -354.30432116]),
#    'bestfit': -427.5102143577257,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-57.87979188, 421.35330748]),
#    'fit': -347.3017279880336,
#    'bestpos': array([-57.87979188, 421.35330748]),
#    'bestfit': -347.3017279880336,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 235.35929969, -506.55802648]),
#    'fit': -205.39738519183072,
#    'bestpos': array([ 235.35929969, -506.55802648]),
#    'bestfit': -205.39738519183072,
#    'bestvois': None}],
#  [{'vit': array([0., 0.]),
#    'pos': array([ 409.03993394, -389.2896348 ]),
#    'fit': 41.17171117724604,
#    'bestpos': array([ 409.03993394, -389.2896348 ]),
#    'bestfit': 41.17171117724604,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-170.87244088,  -66.71175652]),
#    'fit': 149.02698814435146,
#    'bestpos': array([-170.87244088,  -66.71175652]),
#    'bestfit': 149.02698814435146,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 50.48791634, 297.32204861]),
#    'fit': -176.4573989253771,
#    'bestpos': array([ 50.48791634, 297.32204861]),
#    'bestfit': -176.4573989253771,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 333.3332307 , -367.58951247]),
#    'fit': -317.4525858768485,
#    'bestpos': array([ 333.3332307 , -367.58951247]),
#    'bestfit': -317.4525858768485,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([310.4289964 , 266.86094859]),
#    'fit': -74.0917346698341,
#    'bestpos': array([310.4289964 , 266.86094859]),
#    'bestfit': -74.0917346698341,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-414.80190247,  435.47368339]),
#    'fit': 342.95139999017937,
#    'bestpos': array([-414.80190247,  435.47368339]),
#    'bestfit': 342.95139999017937,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-282.72459453,  347.57837179]),
#    'fit': -154.72482614179805,
#    'bestpos': array([-282.72459453,  347.57837179]),
#    'bestfit': -154.72482614179805,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ -66.48491693, -439.85679752]),
#    'fit': 449.4894473499917,
#    'bestpos': array([ -66.48491693, -439.85679752]),
#    'bestfit': 449.4894473499917,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([-184.29380579,   59.30505984]),
#    'fit': 244.92520012798073,
#    'bestpos': array([-184.29380579,   59.30505984]),
#    'bestfit': 244.92520012798073,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 147.67565506, -488.78602468]),
#    'fit': 19.084040753851312,
#    'bestpos': array([ 147.67565506, -488.78602468]),
#    'bestfit': 19.084040753851312,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([  68.56719465, -445.76517948]),
#    'fit': 163.48601614831028,
#    'bestpos': array([  68.56719465, -445.76517948]),
#    'bestfit': 163.48601614831028,
#    'bestvois': None},
#   {'vit': array([0., 0.]),
#    'pos': array([ 170.71102493, -336.560297  ]),
#    'fit': 456.8643379579406,
#    'bestpos': array([ 170.71102493, -336.560297  ]),
#    'bestfit': 456.8643379579406,
#    'bestvois': None}]]

# %%
def plot_swarm_with_plotly(swarm: list, dim: int, infs: list, sups: list, eval_func=get_evaluation_by_name(FUNCTION)):
    """
    Plot the swarm in the search space.
    """
    if dim > 2:
        print("Plotting is only possible for 1D, 2D problems")
        return

    if dim == 1:
        # plot function
        x = np.linspace(infs[0], sups[0], 100)
        fig = go.Figure(data=[go.Scatter(x=x, y=eval_func(x))])

        # Plot the swarm
        for particle in swarm:
            fig.add_trace(go.Scatter(x=[particle["pos"][0]], y=[particle["pos"][1]], mode='markers',
                                     marker=dict(color='red', size=10)))

        fig.update_layout(
            xaxis=dict(range=[infs[0], sups[0]], autorange=False, zeroline=False),
            yaxis=dict(range=[infs[1], sups[1]], autorange=False, zeroline=False),
            title_text="Swarm")

        fig.show()

    elif dim == 2:
        # plot function
        x = np.linspace(infs[0], sups[0], 100)
        y = np.linspace(infs[1], sups[1], 100)
        X, Y = np.meshgrid(x, y)
        Z = eval_func(np.array([X, Y]))
        fig = go.Figure(data=[go.Contour(z=Z, x=x, y=y, colorscale='Viridis')])

        # Plot the swarm
        for particle in swarm:
            fig.add_trace(go.Scatter(x=[particle["pos"][0]], y=[particle["pos"][1]], mode='markers',
                                     marker=dict(color='red', size=10)))

        fig.update_layout(
            #xaxis=dict(range=[infs[0], sups[0]], autorange=False, zeroline=False),
            #yaxis=dict(range=[infs[1], sups[1]], autorange=False, zeroline=False),
            title_text="Swarm",
            title_x=0.5,
            width=800,
            height=800,
        )

    fig.show()


plot_swarm_with_plotly(swarm_test, DIM, INFS, SUPS)
# Out:
# <div>                            <div id="5bb9a6ed-9b52-4778-82a1-2c962af68884" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bb9a6ed-9b52-4778-82a1-2c962af68884")) {                    Plotly.newPlot(                        "5bb9a6ed-9b52-4778-82a1-2c962af68884",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":[-512.0,-501.65656565656565,-491.3131313131313,-480.969696969697,-470.62626262626264,-460.2828282828283,-449.93939393939394,-439.5959595959596,-429.25252525252523,-418.9090909090909,-408.5656565656566,-398.22222222222223,-387.8787878787879,-377.5353535353535,-367.19191919191917,-356.8484848484849,-346.50505050505046,-336.16161616161617,-325.8181818181818,-315.47474747474746,-305.1313131313131,-294.78787878787875,-284.44444444444446,-274.10101010101005,-263.75757575757575,-253.4141414141414,-243.07070707070704,-232.7272727272727,-222.38383838383834,-212.04040404040404,-201.6969696969697,-191.35353535353534,-181.01010101010098,-170.66666666666663,-160.32323232323228,-149.97979797979792,-139.63636363636363,-129.29292929292927,-118.94949494949492,-108.60606060606057,-98.26262626262621,-87.91919191919186,-77.57575757575756,-67.23232323232321,-56.88888888888886,-46.545454545454504,-36.20202020202015,-25.858585858585798,-15.515151515151501,-5.171717171717148,5.171717171717205,15.515151515151615,25.85858585858591,36.20202020202021,46.54545454545462,56.888888888888914,67.23232323232332,77.57575757575762,87.91919191919192,98.26262626262633,108.60606060606062,118.94949494949503,129.29292929292933,139.63636363636374,149.97979797979804,160.32323232323233,170.66666666666674,181.01010101010104,191.35353535353545,201.69696969696975,212.04040404040416,222.38383838383845,232.72727272727275,243.07070707070716,253.41414141414145,263.75757575757586,274.10101010101016,284.44444444444446,294.78787878787887,305.13131313131316,315.4747474747476,325.81818181818187,336.1616161616163,346.5050505050506,356.8484848484849,367.1919191919193,377.5353535353536,387.878787878788,398.2222222222223,408.5656565656567,418.909090909091,429.2525252525253,439.5959595959597,449.939393939394,460.2828282828284,470.6262626262627,480.969696969697,491.3131313131314,501.6565656565657,512.0],"y":[-512.0,-501.65656565656565,-491.3131313131313,-480.969696969697,-470.62626262626264,-460.2828282828283,-449.93939393939394,-439.5959595959596,-429.25252525252523,-418.9090909090909,-408.5656565656566,-398.22222222222223,-387.8787878787879,-377.5353535353535,-367.19191919191917,-356.8484848484849,-346.50505050505046,-336.16161616161617,-325.8181818181818,-315.47474747474746,-305.1313131313131,-294.78787878787875,-284.44444444444446,-274.10101010101005,-263.75757575757575,-253.4141414141414,-243.07070707070704,-232.7272727272727,-222.38383838383834,-212.04040404040404,-201.6969696969697,-191.35353535353534,-181.01010101010098,-170.66666666666663,-160.32323232323228,-149.97979797979792,-139.63636363636363,-129.29292929292927,-118.94949494949492,-108.60606060606057,-98.26262626262621,-87.91919191919186,-77.57575757575756,-67.23232323232321,-56.88888888888886,-46.545454545454504,-36.20202020202015,-25.858585858585798,-15.515151515151501,-5.171717171717148,5.171717171717205,15.515151515151615,25.85858585858591,36.20202020202021,46.54545454545462,56.888888888888914,67.23232323232332,77.57575757575762,87.91919191919192,98.26262626262633,108.60606060606062,118.94949494949503,129.29292929292933,139.63636363636374,149.97979797979804,160.32323232323233,170.66666666666674,181.01010 ...

# %% [markdown]
# ## Particle Update

# %%
# compare two particles and return True if the first one is better than the second one
def is_better(p1, p2):
    return p1["fit"] < p2["fit"]

# Return the particle with the best fitness
def max_particle(p1, p2):
    if is_better(p1, p2):
        return p1
    else:
        return p2

# Returns a copy of the particle with the best fitness in the population
def get_best_particles(swarm):
    return reduce(max_particle, swarm)


get_best_particles(swarm_test)
# Out:
# {'vit': array([0., 0.]),
#  'pos': array([-464.51896933,  119.67270077]),
#  'fit': -592.3062133151341,
#  'bestpos': array([-464.51896933,  119.67270077]),
#  'bestfit': -592.3062133151341,
#  'bestvois': None}

# %%
# function to stop at boundaries of the search space

position_new = swarm_test[0]["pos"]
print(position_new)
np.clip(position_new, [-145] * len(position_new), [145] * len(position_new))
# Out:
# [-250.65376739 -459.85785562]
# array([-145., -145.])

# %%
# Update information of the particle, add information about the best neighbor
def update_best_info(particle, best_particle):
    particle["bestvois"] = dict(best_particle)
    if (particle["fit"] < particle["bestfit"]):
        particle["bestfit"] = particle["fit"]
        particle["bestpos"] = particle["pos"][:]
    return particle


print(swarm_test[0])
update_best_info(swarm_test[0], get_best_particles(swarm_test))
# Out:
# {'vit': array([0., 0.]), 'pos': array([-250.65376739, -459.85785562]), 'fit': -459.62756592915923, 'bestpos': array([-250.65376739, -459.85785562]), 'bestfit': -459.62756592915923, 'bestvois': None}
# {'vit': array([0., 0.]),
#  'pos': array([-250.65376739, -459.85785562]),
#  'fit': -459.62756592915923,
#  'bestpos': array([-250.65376739, -459.85785562]),
#  'bestfit': -459.62756592915923,
#  'bestvois': {'vit': array([0., 0.]),
#   'pos': array([-464.51896933,  119.67270077]),
#   'fit': -592.3062133151341,
#   'bestpos': array([-464.51896933,  119.67270077]),
#   'bestfit': -592.3062133151341,
#   'bestvois': None}}

# %%
# Update information of swarm
def update_best_info_swarm(swarm, best_particle):
    #best_particle = get_best_of_the_swarm(swarm)
    return [update_best_info(particle, best_particle) for particle in swarm]

# %% [markdown]
# ### Move
#
# ![image.png](images/particle_update.png)

# %%
# Calculate the velocity and move a particle
def move_particle(particle, dim: int, psi: float, cmax: float, infs: list, sups: list,
                  eval_func=get_evaluation_by_name(FUNCTION)):
    rho1 = np.array([cmax * np.random.uniform(0,2) for _ in range(dim)])

    rho2 = np.array([cmax * np.random.uniform(0,2) for _ in range(dim)])

    # Velocity calculation (V_new = psi*V_old + rho1 * (bestpos - pos) + rho2 * (bestvois - pos))
    velocity_new = particle["vit"] * psi + rho1 * (particle["bestpos"] - particle["pos"]) + rho2 * (
            particle["bestvois"]["pos"] - particle["pos"])
    # New position calculation
    position_new = particle["pos"] + velocity_new

    # Bornage : For each dimension, if the particle is out of the search space, we put it back in
    position_new = np.clip(position_new, infs, sups)

    # Evaluation of the new position
    evaluation_new = eval_func(position_new)

    # Update of the particle
    particle["vit"] = velocity_new
    particle["pos"] = position_new
    particle["fit"] = evaluation_new

    return particle


print(swarm_test[0])
move_particle(swarm_test[0], DIM, PSI, CMAX, INFS, SUPS)
# Out:
# {'vit': array([0., 0.]), 'pos': array([-250.65376739, -459.85785562]), 'fit': -459.62756592915923, 'bestpos': array([-250.65376739, -459.85785562]), 'bestfit': -459.62756592915923, 'bestvois': {'vit': array([0., 0.]), 'pos': array([-464.51896933,  119.67270077]), 'fit': -592.3062133151341, 'bestpos': array([-464.51896933,  119.67270077]), 'bestfit': -592.3062133151341, 'bestvois': None}}
# {'vit': array([-304.26315713,  487.22732131]),
#  'pos': array([-512.        ,   27.36946569]),
#  'fit': -159.58643045791177,
#  'bestpos': array([-250.65376739, -459.85785562]),
#  'bestfit': -459.62756592915923,
#  'bestvois': {'vit': array([0., 0.]),
#   'pos': array([-464.51896933,  119.67270077]),
#   'fit': -592.3062133151341,
#   'bestpos': array([-464.51896933,  119.67270077]),
#   'bestfit': -592.3062133151341,
#   'bestvois': None}}

# %%
def move_swarm(swarm: list, dim: int, psi: float, cmax: float, infs: list, sups: list,
               eval_func=get_evaluation_by_name(FUNCTION)):
    return [move_particle(particle, dim, psi, cmax, infs, sups, eval_func) for particle in swarm]

# %% [markdown]
# ## PSO algorithm

# %% [markdown]
# ### Convergence criteria
#
# Stop the algorithm when the average distance between all particles in the population is less than a threshold.
#
# Pour évaluer à quel point les particules dans votre population sont proches les unes des autres, on va utiliser la distance moyenne entre les positions de toutes les particules dans la population.

# %%
def evaluate_cohesion(population: list) -> float:
    """
    Return the average distance between all particles in the population.
    """
    num_particles = len(population)
    total_distance = 0
    for i in range(num_particles):
        for j in range(i + 1, num_particles):
            distance = np.linalg.norm(population[i]['pos'] - population[j]['pos'])  # euclidean distance
            total_distance += distance
    avg_distance = total_distance / (num_particles * (num_particles - 1) / 2)
    return avg_distance


evaluate_cohesion(swarm_test)
# Out:
# 519.2644729710781

# %% [markdown]
# ### Plotting functions

# %%
def print_solution(best):
    print("  point = {}".format(best['pos']))
    print("  eval = {}".format(best['fit']))


def plot_history(h_best_particle, h_cohesion, title=""):
    # Plot the evolution of the best fit and cohesion (subplots)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    fig.suptitle(title)
    ax1.plot([h_best_particle[i]['fit'] for i in range(len(h_best_particle))], color='green')
    ax1.set_title('Evolution of the best fit')
    ax1.set_xlabel('Iteration')
    ax1.set_ylabel('Minimum fitness')

    ax2.plot(h_cohesion, color='orange')
    ax2.set_title('Evolution of the cohesion')
    ax2.set_xlabel('Iteration')
    ax2.set_ylabel('Cohesion')

    plt.show()

def plot_history_swarm(history_swarm: list, dim: int, infs: list, sups: list, eval_func=get_evaluation_by_name(FUNCTION),
                       title: str = "Swarm History", n_subplots: int = 5):

    if (dim > 2):
        print("Plotting is only possible for 2D and 3D problems")
        return

    if (dim == 2):
        len_history = len(history_swarm)
        step = len_history // n_subplots if len_history > n_subplots else 1
        indexes = list(range(0,len_history,step))
        indexes = indexes + [len_history-1] if indexes[-1] != len_history-1 else indexes
        indexes = indexes[:-2] + [indexes[-1]] if len(indexes) > n_subplots else indexes
        swarm_to_plot = [history_swarm[k] for k in indexes]
        # make n subplots
        fig = plt.figure(figsize=(14, int(6*n_subplots/3)))
        fig.suptitle(title, fontsize=16)
        for i, swarm in enumerate(swarm_to_plot, start=0):
            # plot function
            ax = fig.add_subplot(n_subplots,3, i+1)
            x = np.linspace(infs[0], sups[0], 100)
            y = np.linspace(infs[1], sups[1], 100)
            X, Y = np.meshgrid(x, y)
            Z = eval_func(np.array([X, Y]))
            ax.contour(X, Y, Z, 20, cmap='viridis', zorder=0)
            # add range bar on the right
            fig.colorbar(ax.contourf(X, Y, Z, 20, cmap='viridis'), ax=ax, shrink=0.9, aspect=10)
            # Plot the swarm (top view)
            ax.set_xlim(infs[0], sups[0])
            ax.set_ylim(infs[1], sups[1])
            ax.set_xlabel("x1")
            ax.set_ylabel("x2")
            ax.set_title(" - iteration " + str(indexes[i]))
            # Plot the swarm
            for particle in swarm:
                ax.scatter(particle["pos"][0], particle["pos"][1], color="red", s=50, zorder=10, marker="x")
    fig.tight_layout()
    plt.show()

# %% [markdown]
# ### Main algorithm

# %%
def pso_algorithm_continu(n_particles: int, iter_max: int, dim: int, infs: list, sups: list,
                          eval_func, psi: float = PSI, cmax: float = CMAX,
                          verbose: bool = True, display_history: bool = True, display_swarm_plots=True, iter_swarm_plots : list = [],
                          epsilon_coherence: float = 0.0000001, max_iter_no_improvement: int = 15 ):
    if verbose:
        print(">>> Start PSO algorithm")
        print(">>> Parameters :")
        print(f" * n_particles = {n_particles}")
        print(f" * iter_max = {iter_max}")
        print(f" * dim = {dim}")
        print(f" * eval_func = {eval_func.__name__}")
        print(f" * psi = {psi}")
        print(f" * cmax = {cmax}")
        print(f" * epsilon_coherence = {epsilon_coherence}")
        print(f" * max_iter_no_improvement = {max_iter_no_improvement}")


    # initialization of the population
    swarm = init_swarm(n_particles, dim, infs, sups)
    plot_swarm(swarm, dim, infs, sups, title=f"Initial Swarm (iter = 0)") if display_swarm_plots else None
    # initialization of the best solution
    best_of_the_swarm = get_best_particles(swarm)
    history_best_particle = [best_of_the_swarm]
    history_cohesion = [evaluate_cohesion(swarm)]
    history_swarm = [swarm]
    iter_no_improvement = 0
    if verbose:
        range_iter = tqdm(range(iter_max))
    else:
        range_iter = range(iter_max)
    for i in range_iter:
        # update informations
        swarm = update_best_info_swarm(swarm, best_of_the_swarm)  # tout le monde enregeristre la position du plus beau
        # velocity calculations and displacement
        swarm = move_swarm(swarm, dim, psi, cmax, infs, sups, eval_func)
        # update of the best solution
        best_of_the_swarm = get_best_particles(swarm)


        # historization of data
        history_best_particle.append(best_of_the_swarm)  # historisation de la meilleure particule
        history_cohesion.append(evaluate_cohesion(swarm))  # historisation de la cohesion
        history_swarm.append(swarm)  # historisation de l'etat de la population

        # check if the swarm is too coherent
        if history_cohesion[-1] < epsilon_coherence:
            if verbose:
                print(f">>> Break : cohesion < epsilon={epsilon_coherence}")
            break

        # check if no improvement since a while
        if history_best_particle[-1]["fit"] == history_best_particle[-2]["fit"]:
            iter_no_improvement += 1
            if iter_no_improvement >= max_iter_no_improvement:
                if verbose:
                    print(f">>> Break : no improvement since {max_iter_no_improvement} iterations")
                break
        else:
            iter_no_improvement = 0


    if display_swarm_plots and iter_swarm_plots:
        for i_to_plot in iter_swarm_plots:
            if i_to_plot < i+1:
                plot_swarm(history_swarm[i_to_plot], dim, infs, sups, title=f"Swarm (iter = {i_to_plot})")
    plot_swarm(swarm, dim, infs, sups, title=f"Final Swarm (iter = {i+1})") if display_swarm_plots else None
    # get the best solution since the beginning
    best_since_beginning = get_best_particles(history_best_particle)
    best_at_end = get_best_particles(swarm)
    # displaying result
    if verbose:
        print("History size : ", len(history_best_particle))
        print(">>> Results after", i, "iterations :")
        print("> Best solution since the beginning :")
        print_solution(best_since_beginning)
        print("> Best solution at the end :")
        print_solution(best_at_end)

    # display history
    if display_history:
        print(">>> Display history :")
        plot_history(history_best_particle, history_cohesion)
    # delete history_swarm
    del history_swarm
    return best_since_beginning, best_at_end, history_best_particle, history_cohesion


best_since_beginning, best_at_end, history_best_particle, history_cohesion = pso_algorithm_continu(
    n_particles=N_PARTICLES, iter_max=ITER_MAX,
    dim=DIM, infs=INFS, sups=SUPS,
    eval_func=get_evaluation_by_name(FUNCTION),
    psi=PSI, cmax=CMAX, iter_swarm_plots=[10,50], max_iter_no_improvement = 30 )
# Out:
# >>> Start PSO algorithm
# >>> Parameters :
#  * n_particles = 12
#  * iter_max = 1000
#  * dim = 2
#  * eval_func = eggholder
#  * psi = 0.7
#  * cmax = 1.47
#  * epsilon_coherence = 1e-07
#  * max_iter_no_improvement = 30
#  35%|███▍      | 348/1000 [00:00<00:01, 359.79it/s]
# >>> Break : no improvement since 30 iterations
# History size :  350
# >>> Results after 348 iterations :
# > Best solution since the beginning :
#   point = [-512.          413.69114107]
#   eval = -955.6087226985212
# > Best solution at the end :
#   point = [-512.          413.69114107]
#   eval = -955.6087226985212
# >>> Display history :

# %% [markdown]
# ## Multiple execution
# Multiple execution with same parameters

# %%
def pso_algorithm_continu_n_runs(n_runs: int, n_particles: int, iter_max: int, dim: int, infs: list, sups: list,
                                 eval_func=get_evaluation_by_name(FUNCTION), psi: float = PSI, cmax: float = CMAX,
                                 epsilon: float = 0.0001):
    solutions_outputs = []
    for _ in tqdm(range(n_runs)):
        best_since_beginning, best_at_end, history_best_particle, history_cohesion = pso_algorithm_continu(
            n_particles=n_particles, iter_max=iter_max,
            dim=dim, infs=infs, sups=sups,
            eval_func=eval_func,
            psi=psi, cmax=cmax, verbose=False, display_history=False, display_swarm_plots=False, epsilon_coherence=epsilon)
        solutions_outputs.append(
            best_since_beginning)  # on enregistre la meilleure solution depuis le debut de l'execution
    return solutions_outputs, get_best_particles(solutions_outputs)


N_RUNS = 50
solutions_outputs, best_solution_after_n_runs = pso_algorithm_continu_n_runs(n_runs=N_RUNS, n_particles=N_PARTICLES,
                                                                             iter_max=ITER_MAX, dim=DIM, infs=INFS,
                                                                             sups=SUPS,
                                                                             eval_func=get_evaluation_by_name(FUNCTION),
                                                                             psi=PSI, cmax=CMAX)
# Out:
# 100%|██████████| 50/50 [00:31<00:00,  1.57it/s]

# %% [markdown]
# ### Display results

# %%
print_solution(best_solution_after_n_runs)
# Out:
#   point = [-512.          413.69113612]
#   eval = -955.6087226985308

# %%
solutions_outputs_fit = np.array([sol["fit"] for sol in solutions_outputs])

print("Count: %d \nMean: %.1f \nStd: %.1f \nMin: %.1f \nMax: %.1f" % (
    len(solutions_outputs_fit), solutions_outputs_fit.mean(), solutions_outputs_fit.std(), solutions_outputs_fit.min(),
    solutions_outputs_fit.max()))

fig1, axs = plt.subplots(1, 1, tight_layout=True, figsize=(5, 5))

title = f'PSO Results after %d runs (f=%s, dim=%d, psi=%.2f, cmax=%.2f)' % (
    N_RUNS, FUNCTION, DIM, PSI, CMAX)

axs.set_title(title)
axs.boxplot(solutions_outputs_fit)

plt.show()

fig1.savefig(
    '%s/PSO Results (f=%s, dim=%d, nb_particles=%d,  inf=%d, sup=%d, psi=%.2f, cmax=%.2f, iter_max=%d) after %d runs (best=%.2f).png' % (
        "plots", FUNCTION, DIM, N_PARTICLES, INFS[0], SUPS[0], PSI, CMAX, ITER_MAX, N_RUNS,
        best_solution_after_n_runs.get("fit")))
# Out:
# Count: 50
# Mean: -822.4
# Std: 120.2
# Min: -955.6
# Max: -622.0

# %% [markdown]
# ## Ressources & Notes
#
# - https://www.youtube.com/watch?v=JhgDMAm-imI
# - https://towardsdatascience.com/particle-swarm-optimization-visually-explained-46289eeb2e14

# %% [markdown]
# > *inertia*, *cognitive* and *social coefficients*.
#
# These coefficients control the levels of exploration and exploitation.
#
# * **Exploitation** is the ability of particles to target the best solutions found so far.
# * **Exploration**, on the other hand, is the ability of particles to evaluate the entire research space.
#
# The challenge will be to determine the impact of these coefficients to find a good balance between exploration and exploitation.
